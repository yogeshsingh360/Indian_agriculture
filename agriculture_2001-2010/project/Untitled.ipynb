# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
df = pd.read_csv('data_set_of_2001-10.csv')

# %%
df
# Out:
#             State_Name District_Name  Crop_Year      Season          Crop  \
# 0       andhra pradesh     anantapur       2001      kharif     Arhar/Tur
# 1       andhra pradesh     anantapur       2001      kharif         Bajra
# 2       andhra pradesh     anantapur       2001      kharif   Castor seed
# 3       andhra pradesh     anantapur       2001      kharif  Cotton(lint)
# 4       andhra pradesh     anantapur       2001      kharif  Dry chillies
# ...                ...           ...        ...         ...           ...
# 102792     west bengal       purulia       2010        rabi         Wheat
# 102793     west bengal       purulia       2010      summer         Maize
# 102794     west bengal       purulia       2010      summer          Rice
# 102795     west bengal       purulia       2010  whole year     Sugarcane
# 102796     west bengal       purulia       2010      winter          Rice
#
#             Area  Production  temperature_2m_mean  precipitation_sum  \
# ...

# %%
max(df['Production']),min(df['Production']),max(df['Area']),min(df['Area'])
# Out:
# (1063000000.0, 100.1, 1020181.0, 1.0)

# %%
c=df[df['Production']>=1020181]
c
# Out:
#             State_Name District_Name  Crop_Year      Season      Crop  \
# 30      andhra pradesh     anantapur       2001  whole year  Coconut
# 67      andhra pradesh     anantapur       2002  whole year  Coconut
# 108     andhra pradesh     anantapur       2003  whole year  Coconut
# 146     andhra pradesh     anantapur       2004  whole year  Coconut
# 177     andhra pradesh     anantapur       2005  whole year  Coconut
# ...                ...           ...        ...         ...       ...
# 102478     west bengal         nadia       2007      kharif      Jute
# 102500     west bengal         nadia       2007  whole year  Coconut
# 102509     west bengal         nadia       2008      kharif      Jute
# 102537     west bengal         nadia       2009      kharif      Jute
# 102560     west bengal         nadia       2010      kharif      Jute
#
#             Area  Production  temperature_2m_mean  precipitation_sum  \
# ...

# %%
df['Season'].unique()
# Out:
# array(['kharif', 'rabi', 'whole year', 'autumn', 'summer', 'winter'],
#       dtype=object)

# %%
df['Crop'].unique()
# Out:
# array(['Arhar/Tur', 'Bajra', 'Castor seed', 'Cotton(lint)',
#        'Dry chillies', 'Groundnut', 'Jowar', 'Korra', 'Maize',
#        'Moong(Green Gram)', 'Onion', 'Other Kharif pulses', 'Ragi',
#        'Rice', 'Small millets', 'Sunflower', 'Urad', 'Gram', 'Horse-gram',
#        'Safflower', 'Wheat', 'Arecanut', 'Banana', 'Coconut ',
#        'Coriander', 'Sugarcane', 'Sweet potato', 'Tobacco', 'Bhindi',
#        'Brinjal', 'Citrus Fruit', 'Grapes', 'Mango', 'Orange',
#        'Other Fresh Fruits', 'Papaya', 'Pome Fruit', 'Tomato', 'Soyabean',
#        'Mesta', 'Potato', 'Turmeric', 'Samai', 'Sesamum',
#        'Beans & Mutter(Vegetable)', 'Tapioca', 'Other  Rabi pulses',
#        'Cashewnut', 'other oilseeds', 'Rapeseed &Mustard', 'Linseed',
#        'Dry ginger', 'Ginger', 'Varagu', 'Niger seed', 'Oilseeds total',
#        'Pulses total', 'Jute', 'Masoor', 'Peas & beans (Pulses)',
#        'Blackgram', 'Black pepper', 'Pineapple', 'other misc. pulses',
# ...

# %%
df['State_Name'].unique()
# Out:
# array(['andhra pradesh', 'arunachal pradesh', 'assam', 'bihar',
#        'chandigarh', 'chhattisgarh', 'dadra and nagar haveli', 'goa',
#        'gujarat', 'haryana', 'himachal pradesh', 'jammu and kashmir',
#        'jharkhand', 'karnataka', 'kerala', 'madhya pradesh',
#        'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland',
#        'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'telangana', 'tripura', 'uttar pradesh',
#        'uttarakhand', 'west bengal'], dtype=object)

# %%
df['District_Name'].unique()
# Out:
# array(['anantapur', 'chittoor', 'east godavari', 'guntur', 'kadapa',
#        'krishna', 'kurnool', 'prakasam', 'spsr nellore', 'srikakulam',
#        'visakhapatanam', 'vizianagaram', 'west godavari', 'anjaw',
#        'changlang', 'dibang valley', 'east kameng', 'east siang',
#        'kurung kumey', 'lohit', 'lower dibang valley', 'lower subansiri',
#        'papum pare', 'tawang', 'tirap', 'upper siang', 'upper subansiri',
#        'west kameng', 'west siang', 'baksa', 'barpeta', 'bongaigaon',
#        'cachar', 'chirang', 'darrang', 'dhemaji', 'dhubri', 'dibrugarh',
#        'dima hasao', 'goalpara', 'golaghat', 'hailakandi', 'jorhat',
#        'kamrup', 'kamrup metro', 'karbi anglong', 'karimganj',
#        'kokrajhar', 'lakhimpur', 'marigaon', 'nagaon', 'nalbari',
#        'sivasagar', 'sonitpur', 'tinsukia', 'udalguri', 'araria', 'arwal',
#        'aurangabad', 'banka', 'begusarai', 'bhagalpur', 'bhojpur',
# ...

# %%
df.drop(['State_Name','District_Name'],axis=1,inplace=True)

# %%
df['crop_yield']=df['Production']/df['Area']

# %%
df.drop(['Production'],axis=1,inplace=True)

# %%
df
# Out:
#         Crop_Year      Season          Crop      Area  temperature_2m_mean  \
# 0            2001      kharif     Arhar/Tur   27942.0            27.047742
# 1            2001      kharif         Bajra    1595.0            27.047742
# 2            2001      kharif   Castor seed    3191.0            27.047742
# 3            2001      kharif  Cotton(lint)    8552.0            27.047742
# 4            2001      kharif  Dry chillies    3765.0            27.047742
# ...           ...         ...           ...       ...                  ...
# 102792       2010        rabi         Wheat    2013.0            25.307661
# 102793       2010      summer         Maize     258.0            32.531505
# 102794       2010      summer          Rice     105.0            32.531505
# 102795       2010  whole year     Sugarcane     303.0            24.805404
# 102796       2010      winter          Rice  152676.0            19.117312
#
# ...

# %%
df['Crop'].str.lower()
# Out:
# 0            arhar/tur
# 1                bajra
# 2          castor seed
# 3         cotton(lint)
# 4         dry chillies
#               ...
# 102792           wheat
# 102793           maize
# 102794            rice
# 102795       sugarcane
# 102796            rice
# Name: Crop, Length: 102797, dtype: object

# %%
for i in df.columns.drop(['Season','Crop','crop_yield']):
    plt.scatter(df[i],df['crop_yield'])
    plt.xlabel(i)
    plt.ylabel('crop_yield')
    plt.show()

# %%
max(df['crop_yield']),min(df['crop_yield']),max(df['Area']),min(df['Area'])
# Out:
# (38800.0, 0.00034027772106482427, 1020181.0, 1.0)

# %%
# from graph the yield and area values have very large value differences. So we apply Log transformation on crop_yield and area column
df['crop_yield']=np.log1p(df['crop_yield'])
df['Area']=np.log1p(df['Area'])

# %%
for i in df.columns.drop(['Season','Crop','crop_yield']):
    plt.scatter(df[i],df['crop_yield'])
    plt.xlabel(i)
    plt.ylabel('crop_yield')
    plt.show()

# %% [markdown]
# conclusion: most of the features are non-linearly separable and dataset is very large.So, avoid linear model's.
#              So most preferable models are:- CatBoost,LightGBM,XGBoost,Neural Network, RandomForestRegressor.
# -->appling lon1p on crop_yield and area it make more accurate  our model and data can uniformly distrubeted

# %%
df.to_csv('train_test.csv',index=False)
