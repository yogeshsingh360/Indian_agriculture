# %%
import pandas as pd 
df = pd.read_csv("apy.csv")

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df = df.drop(df[df["Crop_Year"]<2001].index)

# %%
df = df.drop(df[df["Crop_Year"]>2010].index)

# %%
df = df.drop(df[df["State_Name"]=="Andaman and Nicobar Islands"].index)

# %%
df=df.drop(df[df['Production']<=100].index)

# %%
df
# Out:
#             State_Name District_Name  Crop_Year       Season          Crop  \
# 336     Andhra Pradesh     ANANTAPUR       2001  Kharif          Arhar/Tur
# 337     Andhra Pradesh     ANANTAPUR       2001  Kharif              Bajra
# 338     Andhra Pradesh     ANANTAPUR       2001  Kharif        Castor seed
# 339     Andhra Pradesh     ANANTAPUR       2001  Kharif       Cotton(lint)
# 340     Andhra Pradesh     ANANTAPUR       2001  Kharif       Dry chillies
# ...                ...           ...        ...          ...           ...
# 245949     West Bengal       PURULIA       2010  Rabi                Wheat
# 245951     West Bengal       PURULIA       2010  Summer              Maize
# 245952     West Bengal       PURULIA       2010  Summer               Rice
# 245953     West Bengal       PURULIA       2010  Whole Year      Sugarcane
# 245954     West Bengal       PURULIA       2010  Winter               Rice
#
#             Area  Production
# 336      27942.0      7628.0
# ...

# %%
a=len(df["District_Name"].unique())
a
# Out:
# 616

# %%
df.to_csv("updated_crop.csv",index=False)
