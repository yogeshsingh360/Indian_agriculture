# %%
import pandas as pd 

df_crop=pd.read_csv("agriculture/updated_crop.csv")

# %%
df_crop
# Out:
#         Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0              336  Andhra Pradesh     ANANTAPUR       2001  Kharif
# 1              337  Andhra Pradesh     ANANTAPUR       2001  Kharif
# 2              338  Andhra Pradesh     ANANTAPUR       2001  Kharif
# 3              339  Andhra Pradesh     ANANTAPUR       2001  Kharif
# 4              340  Andhra Pradesh     ANANTAPUR       2001  Kharif
# ...            ...             ...           ...        ...          ...
# 146633      245951     West Bengal       PURULIA       2010  Summer
# 146634      245952     West Bengal       PURULIA       2010  Summer
# 146635      245953     West Bengal       PURULIA       2010  Whole Year
# 146636      245954     West Bengal       PURULIA       2010  Winter
# 146637      245955     West Bengal       PURULIA       2010  Winter
#
#                 Crop      Area  Production
# 0          Arhar/Tur   27942.0      7628.0
# 1              Bajra    1595.0       526.0
# 2        Castor seed    3191.0       900.0
# 3       Cotton(lint)    8552.0      9055.0
# 4       Dry chillies    3765.0      7127.0
# ...              ...       ...         ...
# 146633         Maize     258.0       391.0
# 146634          Rice     105.0       281.0
# 146635     Sugarcane     303.0     11541.0
# 146636          Rice  152676.0    261435.0
# 146637       Sesamum     244.0        95.0
#
# [146638 rows x 8 columns]

# %%
crops = df_crop[['State_Name', 'District_Name']].drop_duplicates().reset_index(drop=True)

# %%
crops.to_csv("place2001-2010.csv",index=False)
